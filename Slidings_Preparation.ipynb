# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

lonas = pd.read_csv('Data/sedec_lonas.csv',sep=";")

# %%
lonas.head()
# Out:
#     ano            mes  processo_numero colocacao_lona_situacao  \
# 0  2013   02-fevereiro       8002108013                     Sim
# 1     0  Não informado       8003832612                     Não
# 2     0  Não informado       8005348412                     Não
# 3     0  Não informado       8003833212                     Não
# 4  2013       03-marco       8002630913                     Sim
#
#   colocacao_lona_data                       colocacao_lona_justificativa  \
# 0          25/02/2013                                            2-15X08
# 1                 NaN  SOLICITAÇÃO NÃO ATENDIDA PELA GRANDE DEMANDA D...
# 2                 NaN                                     Lona no local.
# 3                 NaN  SOLICITAÇÃO NÃO ATENDIDA PELA GRANDE DEMANDA D...
# 4          05/03/2013                                            1-15X08
#
#    colocacao_lona_metragem  colocacao_lona_qtd_pontos
# 0                      240                          1
# ...

# %%
lonas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8091 entries, 0 to 8090
# Data columns (total 8 columns):
# ano                             8091 non-null int64
# mes                             8091 non-null object
# processo_numero                 8091 non-null int64
# colocacao_lona_situacao         8079 non-null object
# colocacao_lona_data             7043 non-null object
# colocacao_lona_justificativa    4999 non-null object
# colocacao_lona_metragem         8091 non-null int64
# colocacao_lona_qtd_pontos       8091 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 379.3+ KB

# %%
lonas = lonas.rename(columns={'ano':'year','mes':'month','processo_numero':'ID','colocacao_lona_situacao':'in_place',
                      'colocacao_lona_data':'date_of_placement','colocacao_lona_justificativa':'justification',
                      'colocacao_lona_metragem':'length','colocacao_lona_qtd_pontos':'num_points'})
lonas
# Out:
#       year          month          ID in_place date_of_placement  \
# 0     2013   02-fevereiro  8002108013      Sim        25/02/2013
# 1        0  Não informado  8003832612      Não               NaN
# 2        0  Não informado  8005348412      Não               NaN
# 3        0  Não informado  8003833212      Não               NaN
# 4     2013       03-marco  8002630913      Sim        05/03/2013
# ...    ...            ...         ...      ...               ...
# 8086  2019    11-novembro  8125598519      Sim        04/11/2019
# 8087  2019    11-novembro  8127199019      Sim        05/11/2019
# 8088  2019     10-outubro  8124936419      Sim        22/10/2019
# 8089  2019    11-novembro  8124471119      Sim        11/11/2019
# 8090  2019    11-novembro  8131172619      Sim        04/11/2019
#
#                                           justification  length  num_points
# 0                                               2-15X08     240           1
# ...

# %%
lonas_year = lonas.sort_values(by=['year'])
lonas_year.iloc[2000:2010]
# Out:
#      year     month          ID in_place date_of_placement  \
# 904  2012  06-junho  8001610612      Sim        14/06/2012
# 789  2012  06-junho  8002683712      Sim        06/06/2012
# 754  2012   05-maio  8002201212      Sim        08/05/2012
# 795  2012   05-maio  8001216612      Sim        16/05/2012
# 905  2012  04-abril  8001667812      Sim        25/04/2012
# 918  2012  04-abril  8001658912      Sim        25/04/2012
# 706  2012  06-junho  8002483812      Sim        26/06/2012
# 697  2012  06-junho  8002755812      Sim        08/06/2012
# 703  2012  07-julho  8005191812      Sim        12/07/2012
# 794  2012   05-maio  8002008812      Sim        15/05/2012
#
#               justification  length  num_points
# 904                     NaN     240           1
# 789       Colocação de GEL.       0           1
# 754  Colocação em 07/05/12.    1040           1
# 795           lona colocada     240           1
# 905                     NaN     600           1
# ...

# %%
vistorias = pd.read_csv('Data/sedec_vistorias.csv',sep=";")

# %%
vistorias.head()
# Out:
#     ano          mes                avaliador        vistoria_data  \
# 0  2012  12-dezembro  Engenheiro - Área Morro  2012-12-13 14:34:07
# 1  2012  12-dezembro  Engenheiro - Área Morro  2012-12-20 11:59:13
# 2  2012  12-dezembro  Engenheiro - Área Morro  2012-12-21 14:51:29
# 3  2012  12-dezembro  Engenheiro - Área Morro  2012-12-28 10:09:20
# 4  2012  12-dezembro  Engenheiro - Área Morro  2012-12-13 10:50:13
#
#   vistoria_risco        vistoria_localidade vistoria_rpa_codigo  \
# 0        R3 Alto  ALTO DA JAQUEIRA - Jordão                   6
# 1       R2 Médio         Jardim Teresópoles                   4
# 2  R4 Muito Alto                      UR-05                   6
# 3  R4 Muito Alto         ALTO DA BRASILEIRA                   3
# 4  Não informado                      UR-02                   6
#
#   vistoria_microrregiao vistoria_setor  processo_numero
# 0                   6.2          6-SUL       8008472812
# 1                   4.3     4-NORDESTE       8008985512
# ...

# %%
vistorias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15772 entries, 0 to 15771
# Data columns (total 10 columns):
# ano                      15772 non-null int64
# mes                      15772 non-null object
# avaliador                15772 non-null object
# vistoria_data            15505 non-null object
# vistoria_risco           15772 non-null object
# vistoria_localidade      15772 non-null object
# vistoria_rpa_codigo      15772 non-null object
# vistoria_microrregiao    15772 non-null object
# vistoria_setor           15772 non-null object
# processo_numero          15772 non-null int64
# dtypes: int64(2), object(8)
# memory usage: 739.4+ KB

# %%
vistorias = vistorias.rename(columns={'processo_numero':'ID'})
vistorias
# Out:
#         ano          mes                avaliador        vistoria_data  \
# 0      2012  12-dezembro  Engenheiro - Área Morro  2012-12-13 14:34:07
# 1      2012  12-dezembro  Engenheiro - Área Morro  2012-12-20 11:59:13
# 2      2012  12-dezembro  Engenheiro - Área Morro  2012-12-21 14:51:29
# 3      2012  12-dezembro  Engenheiro - Área Morro  2012-12-28 10:09:20
# 4      2012  12-dezembro  Engenheiro - Área Morro  2012-12-13 10:50:13
# ...     ...          ...                      ...                  ...
# 15767  2016     07-julho  Engenheiro - Área Morro  2016-07-19 09:51:27
# 15768  2016     07-julho  Engenheiro - Área Morro  2016-07-28 18:13:23
# 15769  2016     07-julho  Engenheiro - Área Morro  2016-07-28 18:14:57
# 15770  2016     07-julho  Engenheiro - Área Morro  2016-07-28 18:14:34
# 15771  2016     07-julho  Engenheiro - Área Morro  2016-07-28 18:12:38
#
#       vistoria_risco        vistoria_localidade vistoria_rpa_codigo  \
# ...

# %%
lonas_vistorias = lonas.set_index("ID").join(vistorias.set_index("ID"))

# %%
lonas_vistorias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8885 entries, 8000001214 to 8143616318
# Data columns (total 16 columns):
# year                     8885 non-null int64
# month                    8885 non-null object
# in_place                 8873 non-null object
# date_of_placement        7599 non-null object
# justification            5644 non-null object
# length                   8885 non-null int64
# num_points               8885 non-null int64
# ano                      1672 non-null float64
# mes                      1672 non-null object
# avaliador                1672 non-null object
# vistoria_data            1670 non-null object
# vistoria_risco           1672 non-null object
# vistoria_localidade      1672 non-null object
# vistoria_rpa_codigo      1672 non-null object
# vistoria_microrregiao    1672 non-null object
# vistoria_setor           1672 non-null object
# dtypes: float64(1), int64(3), object(12)
# memory usage: 763.6+ KB

# %%
teste.head()
# Out:
#             year          month in_place date_of_placement  \
# ID
# 8000001214  2014     01-janeiro      Sim        07/01/2014
# 8000001413  2013       03-marco      Sim        18/03/2013
# 8000003713     0  Não informado      Não               NaN
# 8000003713     0  Não informado      Não               NaN
# 8000006613  2013     01-janeiro      Sim        03/01/2013
#
#                                                 justification  length  \
# ID
# 8000001214                                                NaN      80
# 8000001413                                                NaN     280
# 8000003713  Porque a Defesa Civil de Jaboatão já colocou l...       0
# 8000003713  Porque a Defesa Civil de Jaboatão já colocou l...       0
# 8000006613                                      lona colocada     120
#
#             num_points     ano         mes          avaliador  \
# ID
# 8000001214           1     NaN         NaN                NaN
# ...

# %%
chamados = pd.read_csv('Data/sedec_chamados.csv',sep=';')
solicitacoes = pd.read_csv('Data/sedec_solicitacoes.csv',sep=';')
ocorrencias = pd.read_csv('Data/sedec_tipo_ocorrencias.csv',sep=';')

# %%
chamados = chamados.rename(columns={'processo_numero':'ID'})
solicitacoes = solicitacoes.rename(columns={'processo_numero':'ID'})
ocorrencias = ocorrencias.rename(columns={'processo_numero':'ID'})

# %%
chamados.head()
# Out:
#     ano          mes          ID solicitacao_data solicitacao_hora  \
# 0  2020   01-janeiro  8000001720       2020-01-01            05:56
# 1  2019  12-dezembro  8146602119       2019-12-10            08:23
# 2  2019  12-dezembro  8146604419       2019-12-10            08:23
# 3  2019  09-setembro  8112538919       2019-09-17            16:36
# 4  2019  09-setembro  8109426919       2019-09-09            14:55
#
#                                solicitacao_descricao solicitacao_regional  \
# 0       TESTE DE ESPELHAMENTO AO QUIKVIEW 01 01 2020             PLANICIE
# 1  USUÁRIO INFORMA QUE O SÍNDICO ESTÁ REALIZANDO ...             PLANICIE
# 2  USUÁRIO INFORMA QUE O SÍNDICO ESTÁ REALIZANDO ...             PLANICIE
# 3  USUÁRIO SOLICITA VISTORIA, INFORMA QUE SUA RES...             PLANICIE
# 4  USUÁRIO INFORMA QUE QUE CASARÃO COSTA AZEVEDO ...             PLANICIE
#
#   solicitacao_bairro solicitacao_localidade        solicitacao_endereco  ...  \
# ...

# %%
chamados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45975 entries, 0 to 45974
# Data columns (total 26 columns):
# ano                           45975 non-null int64
# mes                           45975 non-null object
# ID                            45975 non-null int64
# solicitacao_data              45975 non-null object
# solicitacao_hora              45975 non-null object
# solicitacao_descricao         45975 non-null object
# solicitacao_regional          45964 non-null object
# solicitacao_bairro            45975 non-null object
# solicitacao_localidade        45798 non-null object
# solicitacao_endereco          45971 non-null object
# solicitacao_roteiro           45971 non-null object
# rpa_codigo                    45975 non-null object
# rpa_nome                      45975 non-null object
# solicitacao_microrregiao      43356 non-null object
# solicitacao_plantao           45975 non-null object
# solicitacao_origem_chamado    45975 non-null object
# ...

# %%
lonas_chamados = lonas.set_index("ID").join(chamados.set_index('ID'))

# %%
lonas_chamados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8091 entries, 8000001214 to 8143616318
# Data columns (total 32 columns):
# year                          8091 non-null int64
# month                         8091 non-null object
# in_place                      8079 non-null object
# date_of_placement             7043 non-null object
# justification                 4999 non-null object
# length                        8091 non-null int64
# num_points                    8091 non-null int64
# ano                           8091 non-null int64
# mes                           8091 non-null object
# solicitacao_data              8091 non-null object
# solicitacao_hora              8091 non-null object
# solicitacao_descricao         8091 non-null object
# solicitacao_regional          8091 non-null object
# solicitacao_bairro            8091 non-null object
# solicitacao_localidade        8068 non-null object
# solicitacao_endereco          8090 non-null object
# ...

# %%
lonas_solicitacoes = lonas.set_index("ID").join(solicitacoes.set_index('ID'))
lonas_solicitacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8599 entries, 8000001214 to 8143616318
# Data columns (total 25 columns):
# year                        8599 non-null int64
# month                       8599 non-null object
# in_place                    8585 non-null object
# date_of_placement           7493 non-null object
# justification               5450 non-null object
# length                      8599 non-null int64
# num_points                  8599 non-null int64
# ano                         8599 non-null int64
# mes                         8599 non-null object
# solicitacao_data            8599 non-null object
# solicitacao_hora            8599 non-null object
# solicitacao_descricao       8599 non-null object
# solicitacao_regional        8599 non-null object
# solicitacao_bairro          8599 non-null object
# solicitacao_localidade      8574 non-null object
# solicitacao_endereco        8598 non-null object
# solicitacao_roteiro         8598 non-null object
# ...

# %%
lonas_ocorrencias = lonas.set_index("ID").join(ocorrencias.set_index('ID'))
lonas_ocorrencias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8292 entries, 8000001214 to 8143616318
# Data columns (total 8 columns):
# year                   8292 non-null int64
# month                  8292 non-null object
# in_place               8279 non-null object
# date_of_placement      7216 non-null object
# justification          5181 non-null object
# length                 8292 non-null int64
# num_points             8292 non-null int64
# processo_ocorrencia    2716 non-null object
# dtypes: int64(3), object(5)
# memory usage: 421.1+ KB

# %%
ocorrencias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31622 entries, 0 to 31621
# Data columns (total 2 columns):
# ID                     31622 non-null int64
# processo_ocorrencia    31622 non-null object
# dtypes: int64(1), object(1)
# memory usage: 370.6+ KB

# %%
chamados.head()
# Out:
#     ano          mes          ID solicitacao_data solicitacao_hora  \
# 0  2020   01-janeiro  8000001720       2020-01-01            05:56
# 1  2019  12-dezembro  8146602119       2019-12-10            08:23
# 2  2019  12-dezembro  8146604419       2019-12-10            08:23
# 3  2019  09-setembro  8112538919       2019-09-17            16:36
# 4  2019  09-setembro  8109426919       2019-09-09            14:55
#
#                                solicitacao_descricao solicitacao_regional  \
# 0       TESTE DE ESPELHAMENTO AO QUIKVIEW 01 01 2020             PLANICIE
# 1  USUÁRIO INFORMA QUE O SÍNDICO ESTÁ REALIZANDO ...             PLANICIE
# 2  USUÁRIO INFORMA QUE O SÍNDICO ESTÁ REALIZANDO ...             PLANICIE
# 3  USUÁRIO SOLICITA VISTORIA, INFORMA QUE SUA RES...             PLANICIE
# 4  USUÁRIO INFORMA QUE QUE CASARÃO COSTA AZEVEDO ...             PLANICIE
#
#   solicitacao_bairro solicitacao_localidade        solicitacao_endereco  ...  \
# ...

# %%
chamados['solicitacao_vitimas'].unique()
# Out:
# array(['Não', 'Sim', nan], dtype=object)

# %%
contagem = chamados.solicitacao_vitimas.value_counts()
contagem
# Out:
# Não    28571
# Sim       80
# Name: solicitacao_vitimas, dtype: int64

# %%
fatais = chamados.solicitacao_vitimas_fatais.value_counts()
fatais
# Out:
# Não    28644
# Sim        7
# Name: solicitacao_vitimas_fatais, dtype: int64

# %%
ocorrencias.head()
# Out:
#            ID                      processo_ocorrencia
# 0  8155845218  Não há Ocorrência para essa Solicitação
# 1  8155698018               Deslizamentos de Barreiras
# 2  8155361518    Invasao de Terreno de Auxilio Moradia
# 3  8155337718                  Imoveis com Danos/Risco
# 4  8155296918  Não há Ocorrência para essa Solicitação

# %%
lonas_ocorrencias.head()
# Out:
#             year          month in_place date_of_placement  \
# ID
# 8000001214  2014     01-janeiro      Sim        07/01/2014
# 8000001413  2013       03-marco      Sim        18/03/2013
# 8000003713     0  Não informado      Não               NaN
# 8000006613  2013     01-janeiro      Sim        03/01/2013
# 8000007213  2013     01-janeiro      Sim        03/01/2013
#
#                                                 justification  length  \
# ID
# 8000001214                                                NaN      80
# 8000001413                                                NaN     280
# 8000003713  Porque a Defesa Civil de Jaboatão já colocou l...       0
# 8000006613                                      lona colocada     120
# 8000007213               ROÇAGEM E TALUDE SUPERIOR E INFERIOR     320
#
#             num_points processo_ocorrencia
# ID
# 8000001214           1                 NaN
# 8000001413           1                 NaN
# ...

# %%
o = lonas_ocorrencias.processo_ocorrencia.value_counts()
o
# Out:
# Não há Ocorrência para essa Solicitação               2079
# Deslizamentos de Barreiras                             524
# Arvores em Risco                                        43
# Imoveis com Danos/Risco                                 42
# Muro com Danos                                           8
# Desabamento Parcial Imoveis                              5
# Tombamento de Arvores                                    5
# Imoveis Alagados                                         4
# Desabamento Parcial de Obras de Contencao/Drenagem       2
# Invasao de Terreno de Auxilio Moradia                    2
# Desabamento Total Imoveis                                1
# Desabamento Total de Obras de Contencao/Drenagem         1
# Name: processo_ocorrencia, dtype: int64

# %%
a = lonas_ocorrencias.justification.value_counts()
a
# Out:
# lona colocada                                                                                                                            293
# Devido a chegada do período de estiagem, estão supensas as colocações de lonas nas áreas de risco, até alguma mudança da pluvimetria.    205
# LONA COLOCADA                                                                                                                            189
# 1-15x08                                                                                                                                  175
# LONA COLOCADA.                                                                                                                           137
#                                                                                                                                         ...
# Recibo 53054                                                                                                                               1
# ...
