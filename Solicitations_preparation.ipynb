# %%
import pandas as pd
import numpy as np

solicitations=pd.read_csv("Data\sedec_solicitacoes.csv",delimiter =';')

# %%
solicitations = solicitations.rename(columns={'processo_numero':'ID'})


solicitations.drop(columns='processo_origem', axis=1, inplace=True)

# %%
solicitations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49934 entries, 0 to 49933
# Data columns (total 18 columns):
# ano                         49934 non-null int64
# mes                         49934 non-null object
# ID                          49934 non-null int64
# solicitacao_data            49934 non-null object
# solicitacao_hora            49934 non-null object
# solicitacao_descricao       49934 non-null object
# solicitacao_regional        49921 non-null object
# solicitacao_bairro          49934 non-null object
# solicitacao_localidade      49742 non-null object
# solicitacao_endereco        49930 non-null object
# solicitacao_roteiro         49930 non-null object
# rpa_codigo                  49934 non-null object
# rpa_nome                    49934 non-null object
# solicitacao_microrregiao    47302 non-null object
# solicitacao_plantao         49934 non-null object
# processo_situacao           49786 non-null object
# processo_tipo               49934 non-null object
# processo_solicitacao        32607 non-null object
# dtypes: int64(2), object(16)
# memory usage: 3.8+ MB

# %%
solicitations.head()
# Out:
#     ano          mes          ID solicitacao_data solicitacao_hora  \
# 0  2020   01-janeiro  8000001720       2020-01-01            05:56
# 1  2019  12-dezembro  8146602119       2019-12-10            08:23
# 2  2019  12-dezembro  8146604419       2019-12-10            08:23
# 3  2019  09-setembro  8112538919       2019-09-17            16:36
# 4  2019  09-setembro  8109426919       2019-09-09            14:55
#
#                                solicitacao_descricao solicitacao_regional  \
# 0       TESTE DE ESPELHAMENTO AO QUIKVIEW 01 01 2020             PLANICIE
# 1  USUÁRIO INFORMA QUE O SÍNDICO ESTÁ REALIZANDO ...             PLANICIE
# 2  USUÁRIO INFORMA QUE O SÍNDICO ESTÁ REALIZANDO ...             PLANICIE
# 3  USUÁRIO SOLICITA VISTORIA, INFORMA QUE SUA RES...             PLANICIE
# 4  USUÁRIO INFORMA QUE QUE CASARÃO COSTA AZEVEDO ...             PLANICIE
#
#   solicitacao_bairro solicitacao_localidade        solicitacao_endereco  \
# 0            AFLITOS                AFLITOS                     RUA AAA
# 1            AFLITOS                AFLITOS    RUA CARNEIRO VILELA, 343
# 2            AFLITOS                AFLITOS    RUA CARNEIRO VILELA, 343
# 3            AFLITOS                AFLITOS    AV SANTOS DUMONT , N 290
# 4            AFLITOS                AFLITOS  AV CONS ROSA E SILVA N 707
#
#                                  solicitacao_roteiro rpa_codigo    rpa_nome  \
# 0       TESTE DE ESPELHAMENTO AO QUIKVIEW 01 01 2020          3  3-NOROESTE
# 1  NA RUA DA IGREJA EPISCOPAL, PRÓXIMO A GALERIA ...          3  3-NOROESTE
# 2  NA RUA DA IGREJA EPISCOPAL, PRÓXIMO A GALERIA ...          3  3-NOROESTE
# 3  DEPOIS DO NÁUTICO A 1 ª A DIREITA , ESQUINA CO...          3  3-NOROESTE
# 4                    EM FRENTE IGREJINHA DOS AFLITOS          3  3-NOROESTE
#
#   solicitacao_microrregiao solicitacao_plantao processo_situacao  \
# 0                      3.1                 Sim          execucao
# 1                      3.1                 Não          completo
# 2                      3.1                 Não          completo
# 3                      3.1                 Sim          completo
# 4                      3.1                 Não          completo
#
#   processo_tipo processo_solicitacao
# 0   ATENDIMENTO             Vistoria
# 1   ATENDIMENTO             Vistoria
# 2   ATENDIMENTO             Vistoria
# 3   ATENDIMENTO             Vistoria
# 4   ATENDIMENTO             Vistoria

# %%
solicitations['processo_situacao'] = solicitations['processo_situacao'].astype('str')
solicitations['solicitacao_descricao'] = solicitations['solicitacao_descricao'].astype('str')
solicitations['solicitacao_descricao'].str.lower()
# Out:
# 0             teste de espelhamento ao quikview 01 01 2020
# 1        usuário informa que o síndico está realizando ...
# 2        usuário informa que o síndico está realizando ...
# 3        usuário solicita vistoria, informa que sua res...
# 4        usuário informa que que casarão costa azevedo ...
#                                ...
# 49929    vistoria em casa .usuaria inf que casa esta co...
# 49930    vistoria em predio, urgente falar com rodrigo ...
# 49931    vistoria em predio, o predio esta caindo aos p...
# 49932    vistoria em muro com urgenciausuario ja possui...
# 49933    fone/9162/3000/a usuaria pede a vistoria do pr...
# Name: solicitacao_descricao, Length: 49934, dtype: object

# %%
solicitations['solicitacao_descricao']=[1 if 'deslizamento' in review else 0 for review in solicitations['solicitacao_descricao']]
solicitations['processo_situacao']=[1 if sit == 'completo' else 0 for sit in solicitations['processo_situacao']]

# %%
solicitations
# Out:
#         ano          mes          ID solicitacao_data solicitacao_hora  \
# 0      2020   01-janeiro  8000001720       2020-01-01            05:56
# 1      2019  12-dezembro  8146602119       2019-12-10            08:23
# 2      2019  12-dezembro  8146604419       2019-12-10            08:23
# 3      2019  09-setembro  8112538919       2019-09-17            16:36
# 4      2019  09-setembro  8109426919       2019-09-09            14:55
# ...     ...          ...         ...              ...              ...
# 49929  2013    08-agosto  8011179413       2013-08-05            12:55
# 49930  2013    08-agosto  8013069113       2013-08-17            05:54
# 49931  2013    08-agosto  8014039913       2013-08-23            19:35
# 49932  2013   01-janeiro  8000210213       2013-01-05            08:21
# 49933  2012  12-dezembro  8009016612       2012-12-11            09:05
#
#        solicitacao_descricao solicitacao_regional solicitacao_bairro  \
# 0                          0             PLANICIE            AFLITOS
# 1                          0             PLANICIE            AFLITOS
# 2                          0             PLANICIE            AFLITOS
# 3                          0             PLANICIE            AFLITOS
# 4                          0             PLANICIE            AFLITOS
# ...                      ...                  ...                ...
# 49929                      0             PLANICIE              ZUMBI
# 49930                      0             PLANICIE              ZUMBI
# 49931                      0                 GART              ZUMBI
# 49932                      0             PLANICIE              ZUMBI
# 49933                      0                 GART              ZUMBI
#
#       solicitacao_localidade                      solicitacao_endereco  \
# 0                    AFLITOS                                   RUA AAA
# 1                    AFLITOS                  RUA CARNEIRO VILELA, 343
# 2                    AFLITOS                  RUA CARNEIRO VILELA, 343
# 3                    AFLITOS                  AV SANTOS DUMONT , N 290
# 4                    AFLITOS                AV CONS ROSA E SILVA N 707
# ...                      ...                                       ...
# 49929       ZUMBI DO PACHECO                      RUA SAO RAFAEL N°242
# 49930                  ZUMBI                         RUA TOMAS GONZAGA
# 49931                  ZUMBI                        TOMAS GONZAGA N 92
# 49932                  ZUMBI  RUA FREI TEOFILO DE VIGOLETA, NUMERO 484
# 49933                  ZUMBI               RUA FIDELIS MOLITERNO/N/461
#
#                                      solicitacao_roteiro     rpa_codigo  \
# 0           TESTE DE ESPELHAMENTO AO QUIKVIEW 01 01 2020              3
# 1      NA RUA DA IGREJA EPISCOPAL, PRÓXIMO A GALERIA ...              3
# 2      NA RUA DA IGREJA EPISCOPAL, PRÓXIMO A GALERIA ...              3
# 3      DEPOIS DO NÁUTICO A 1 ª A DIREITA , ESQUINA CO...              3
# 4                        EM FRENTE IGREJINHA DOS AFLITOS              3
# ...                                                  ...            ...
# 49929  PROX A MERCEARIA DO IRMAO CABRAL CONTATO/34755821  Não informada
# 49930  EDF ATEMA, PROX A PADARIA CORPORE E PRAÇA DA T...  Não informada
# 49931           PROX. AO COLEGIO LUBIESKA.CEL. 8737/0646  Não informada
# 49932  32272629 / FIXOVIZINHO AO MERCADINHO PRADO, NA...  Não informada
# 49933  PROX.AO JOQUEI CLUBE,ENTRANDO PELA RUA DA LAMA...  Não informada
#
#             rpa_nome solicitacao_microrregiao solicitacao_plantao  \
# 0         3-NOROESTE                      3.1                 Sim
# 1         3-NOROESTE                      3.1                 Não
# 2         3-NOROESTE                      3.1                 Não
# 3         3-NOROESTE                      3.1                 Sim
# 4         3-NOROESTE                      3.1                 Não
# ...              ...                      ...                 ...
# 49929  Não informado             NORDESTE - 1                 Não
# 49930  Não informado             NORDESTE - 1                 Sim
# 49931  Não informado             NORDESTE - 1                 Sim
# 49932  Não informado             NORDESTE - 1                 Sim
# 49933  Não informado             NORDESTE - 1                 Não
#
#        processo_situacao processo_tipo processo_solicitacao
# 0                      0   ATENDIMENTO             Vistoria
# 1                      1   ATENDIMENTO             Vistoria
# 2                      1   ATENDIMENTO             Vistoria
# 3                      1   ATENDIMENTO             Vistoria
# 4                      1   ATENDIMENTO             Vistoria
# ...                  ...           ...                  ...
# 49929                  1   ATENDIMENTO                  NaN
# 49930                  1   ATENDIMENTO                  NaN
# 49931                  1   ATENDIMENTO                  NaN
# 49932                  1   ATENDIMENTO                  NaN
# 49933                  1   ATENDIMENTO                  NaN
#
# [49934 rows x 18 columns]

# %%
solicitations.drop(columns='solicitacao_hora', axis=1, inplace=True)
solicitations.drop(columns='solicitacao_plantao', axis=1, inplace=True)
solicitations.drop(columns='solicitacao_localidade', axis=1, inplace=True)
solicitations.drop(columns='rpa_nome', axis=1, inplace=True)
solicitations.drop(columns='rpa_codigo', axis=1, inplace=True)
solicitations.drop(columns='solicitacao_regional', axis=1, inplace=True)
solicitations.drop(columns='solicitacao_microrregiao', axis=1, inplace=True)
solicitations.drop(columns='solicitacao_endereco', axis=1, inplace=True)
solicitations.drop(columns='solicitacao_roteiro', axis=1, inplace=True)
solicitations.drop(columns='processo_solicitacao', axis=1, inplace=True)
solicitations.head()
# Out:
#     ano          mes          ID solicitacao_data  solicitacao_descricao  \
# 0  2020   01-janeiro  8000001720       2020-01-01                      0
# 1  2019  12-dezembro  8146602119       2019-12-10                      0
# 2  2019  12-dezembro  8146604419       2019-12-10                      0
# 3  2019  09-setembro  8112538919       2019-09-17                      0
# 4  2019  09-setembro  8109426919       2019-09-09                      0
#
#   solicitacao_bairro  processo_situacao processo_tipo
# 0            AFLITOS                  0   ATENDIMENTO
# 1            AFLITOS                  1   ATENDIMENTO
# 2            AFLITOS                  1   ATENDIMENTO
# 3            AFLITOS                  1   ATENDIMENTO
# 4            AFLITOS                  1   ATENDIMENTO

# %%
solicitations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49934 entries, 0 to 49933
# Data columns (total 8 columns):
# ano                      49934 non-null int64
# mes                      49934 non-null object
# ID                       49934 non-null int64
# solicitacao_data         49934 non-null object
# solicitacao_descricao    49934 non-null int64
# solicitacao_bairro       49934 non-null object
# processo_situacao        49934 non-null int64
# processo_tipo            49934 non-null object
# dtypes: int64(4), object(4)
# memory usage: 2.3+ MB

# %%
solicitations = solicitations.rename(columns={'ano':'year','mes':'month','solicitacao_data':'day',
                                 'solicitacao_descricao':'description','solicitacao_bairro':'neighbourhood',
                                 'processo_situacao':'situation'})
solicitations.head()
# Out:
#    year        month          ID         day  description neighbourhood  \
# 0  2020   01-janeiro  8000001720  2020-01-01            0       AFLITOS
# 1  2019  12-dezembro  8146602119  2019-12-10            0       AFLITOS
# 2  2019  12-dezembro  8146604419  2019-12-10            0       AFLITOS
# 3  2019  09-setembro  8112538919  2019-09-17            0       AFLITOS
# 4  2019  09-setembro  8109426919  2019-09-09            0       AFLITOS
#
#    situation processo_tipo
# 0          0   ATENDIMENTO
# 1          1   ATENDIMENTO
# 2          1   ATENDIMENTO
# 3          1   ATENDIMENTO
# 4          1   ATENDIMENTO

# %%
solicitations = solicitations.sort_values('description', ascending=False).drop_duplicates('ID').sort_index()
solicitations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46055 entries, 0 to 49933
# Data columns (total 8 columns):
# year             46055 non-null int64
# month            46055 non-null object
# ID               46055 non-null int64
# day              46055 non-null object
# description      46055 non-null int64
# neighbourhood    46055 non-null object
# situation        46055 non-null int64
# processo_tipo    46055 non-null object
# dtypes: int64(4), object(4)
# memory usage: 2.5+ MB

# %%
aux=[]
for i in range (0,len(solicitations['month'])):
    aux = solicitations.loc[solicitations.index[i],'month']
    solicitations.loc[solicitations.index[i],'month'] = aux[:2]
    solicitations.loc[solicitations.index[i],'month'] = int(solicitations.loc[solicitations.index[i],'month'])

solicitations['month'][:10]
# Out:
# 0     1
# 1    12
# 2    12
# 3     9
# 4     9
# 5     6
# 6    10
# 7    10
# 8     5
# 9     4
# Name: month, dtype: int64

# %%
aux=[]
for i in range (0,len(solicitations['day'])):
    aux = solicitations.loc[solicitations.index[i],'day']
    solicitations.loc[solicitations.index[i],'day'] = aux[-2:]
    
solicitations['day'][:10]
# Out:
# 0    01
# 1    10
# 2    10
# 3    17
# 4    09
# 5    17
# 6    22
# 7    22
# 8    04
# 9    02
# Name: day, dtype: object

# %%
solicitations.head()
# Out:
#    year  month          ID day  description neighbourhood  situation  \
# 0  2020      1  8000001720  01            0       AFLITOS          0
# 1  2019     12  8146602119  10            0       AFLITOS          1
# 2  2019     12  8146604419  10            0       AFLITOS          1
# 3  2019      9  8112538919  17            0       AFLITOS          1
# 4  2019      9  8109426919  09            0       AFLITOS          1
#
#   processo_tipo
# 0   ATENDIMENTO
# 1   ATENDIMENTO
# 2   ATENDIMENTO
# 3   ATENDIMENTO
# 4   ATENDIMENTO

# %%
solicitations['day'] = solicitations['day'].astype(int)
solicitations.head()
# Out:
#    year  month          ID  day  description neighbourhood  situation  \
# 0  2020      1  8000001720    1            0       AFLITOS          0
# 1  2019     12  8146602119   10            0       AFLITOS          1
# 2  2019     12  8146604419   10            0       AFLITOS          1
# 3  2019      9  8112538919   17            0       AFLITOS          1
# 4  2019      9  8109426919    9            0       AFLITOS          1
#
#   processo_tipo
# 0   ATENDIMENTO
# 1   ATENDIMENTO
# 2   ATENDIMENTO
# 3   ATENDIMENTO
# 4   ATENDIMENTO

# %%
solicitations = solicitations.drop(columns='processo_tipo',axis=1)
solicitations.head()
# Out:
#    year  month          ID  day  description neighbourhood  situation
# 0  2020      1  8000001720    1            0       AFLITOS          0
# 1  2019     12  8146602119   10            0       AFLITOS          1
# 2  2019     12  8146604419   10            0       AFLITOS          1
# 3  2019      9  8112538919   17            0       AFLITOS          1
# 4  2019      9  8109426919    9            0       AFLITOS          1

# %%
solicitations.to_csv(path_or_buf='solicitations_prepared.csv')

# %%
solicitations['neighbourhood'].value_counts()
# Out:
# IBURA                   9900
# NOVA DESCOBERTA         6444
# DOIS UNIDOS             2822
# JORDAO                  2566
# GUABIRABA               2265
#                         ...
# JARDIM VASCO DA GAMA       1
# CENTRO                     1
# FUNDAO DE FORA             1
# BARRA DE GUABIRABA         1
# CORREGO JOSE IDALINO       1
# Name: neighbourhood, Length: 120, dtype: int64
